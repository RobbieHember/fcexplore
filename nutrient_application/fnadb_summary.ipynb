# %% [markdown]
# # Summary of forest responses to nutrient application
#
# Robbie A Hember, PhD, P.Ag.
# Climate Change and Integrated Planning Branch,<br>
# Office of the Chief Forester,<br>
# Forests Lands, Natural Resource Operations and Rural Development<br>
# Government of British Columbia<br>
# 545 Superior Street, Victoria, Canada<br>
# robert.hember@gov.bc.ca
#
# Last updated: 2021-04-24

# %% [markdown]
# ## Introduction

# %% [markdown]
# This notebook summarizes observed responses to nutrient application in forest ecosystems. The scope includes area-based, multi-year responses of net change in carbon of stemwood, other biomass pools, litter and soils to applications of nitrogen.
#
# In the case of stemwood, almost all observations represent stemwood volume. Values of stemwood volume were converted to biomass based on the mean wood density of each species. No correction for potential responses of wood density to nutrient applicatoin were applied.
#
# The analysis is based on observations that were compiled in the Forest Nutrient Application Database (FNADB). Due to challenges in acquiring many experiments and the burden of requesting data that are not publically available, and digitizing non-tabular reports, it is not yet quite an exhaustive list of available responses.

# %% [markdown]
# ## Prepare session

# %% [markdown]
# Import modules

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
import warnings
from fcgadgets.macgyver import utilities_general as gu
from fcgadgets.cbrunner import cbrun_utilities as cbu
from fcexplore.nutrient_application import fnadb_utilities as util

# %% [markdown]
# Define page styles

# %%
# %matplotlib inline
#plt.style.use('ggplot')
warnings.filterwarnings('ignore')
display(HTML("<style>.container { width:80% !important; } .output {align-items: left; }</style>"))
# Out:
# <style>.container { width:80% !important; } .output {align-items: left; }</style>

# %% [markdown]
# Define graphics parameters

# %%
params_graphic=cbu.Import_GraphicsParameters('FCI_Demo')
plt.rcParams.update(params_graphic)

# %% [markdown]
# Import the Forest Nutrient Application Database

# %%
path=r'C:\Users\rhember\Documents\Data\Nutrient Addition Experiments Database\Nutrient Addition Experiments Database.xlsx'
db=util.ImportDB(path)

# %% [markdown]
# ## Stemwood responses of coastal Douglas-fir

# %%
util.Plot_StemwoodNetGrowth_FDC_1(db)

# %%
util.Plot_StemwoodNetGrowth_FDC_2(db,'Actual')

# %%
util.Plot_StemwoodNetGrowth_FDC_2(db,'Percent')

# %% [markdown]
# ## Stemwood responses of lodgepole pine

# %%
util.Plot_StemwoodNetGrowth_PLI_1(db);

# %% [markdown]
# ## Stemwood response of white spruce

# %%
util.Plot_StemwoodNetGrowth_SW_1(db)

# %% [markdown]
# ### Prepare inputs
# Start to configure the project based on project parameters and scenario parameters in ProjectConfig.xlsx. Set the directory path to the project data.
